# %%
# !pip install mediapipe opencv-python-headless
from google.colab import files
uploaded = files.upload()   # upload your image here
import cv2
import mediapipe as mp
from google.colab.patches import cv2_imshow

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True)
mp_draw = mp.solutions.drawing_utils

# Get correct uploaded image name
image_path = list(uploaded.keys())[0]

# Read image safely
image = cv2.imread(image_path)

# Safety check (IMPORTANT)
if image is None:
    print("❌ Error: Image not loaded. Check file name.")
else:
    print("✅ Image loaded successfully")

    # Convert BGR to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Pose detection
    result = pose.process(image_rgb)

    # Draw landmarks
    if result.pose_landmarks:
        mp_draw.draw_landmarks(
            image,
            result.pose_landmarks,
            mp_pose.POSE_CONNECTIONS
        )

    # Show output
    cv2_imshow(image)
# Out:
# ...
#      <input type="file" id="files-fa8fc993-d723-4ff6-b417-08ece797206e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa8fc993-d723-4ff6-b417-08ece797206e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install mediapipe opencv-python-headless
from google.colab import files

uploaded = files.upload()   # upload your video (e.g., video.mp4)
import cv2
import mediapipe as mp

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_draw = mp.solutions.drawing_utils

# Get uploaded video name
video_path = list(uploaded.keys())[0]

# Read video
cap = cv2.VideoCapture(video_path)

# Get video properties
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps    = cap.get(cv2.CAP_PROP_FPS)

# Output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(
    "pose_output.mp4",
    fourcc,
    fps,
    (width, height)
)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Pose detection
    result = pose.process(rgb_frame)

    # Draw landmarks
    if result.pose_landmarks:
        mp_draw.draw_landmarks(
            frame,
            result.pose_landmarks,
            mp_pose.POSE_CONNECTIONS
        )

    # Write frame to output video
    out.write(frame)

cap.release()
out.release()

print("✅ Pose estimation completed.")
print("📁 Output saved as: pose_output.mp4")
from google.colab import files
files.download("pose_output.mp4")
# Out:
# ...
#      <input type="file" id="files-7246aa29-84d0-46e5-bc6c-dd30bf81c22d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7246aa29-84d0-46e5-bc6c-dd30bf81c22d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
